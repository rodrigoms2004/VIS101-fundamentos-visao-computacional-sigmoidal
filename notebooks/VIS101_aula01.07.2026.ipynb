# %% [markdown]
# # Aula 01/07/2026 - VIS101
#
#
# Capítulo 03 https://visionbook.mit.edu/visionscience.html

# %% [markdown]
# ## Bibliotecas

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from skimage.segmentation import felzenszwalb # pip install scikit-image
import math

# %%
[1, 2, 5, 1, 9]
# Out:
# [1, 2, 5, 1, 9]
